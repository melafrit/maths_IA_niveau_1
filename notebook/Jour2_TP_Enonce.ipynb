# %% [markdown]
# # Mathématiques appliquées à l'Intelligence Artificielle
# ## 📝 Jour 2 : Optimisation
# ## TP Énoncé
#
# 2e année Bachelor Informatique
#
# ---
#
# > © 2025 Mohamed EL AFRIT
# > Ce contenu est distribué sous licence [Creative Commons BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr)
# > [www.mohamedelafrit.com](https://www.mohamedelafrit.com)

# %% [markdown]
# ## ⚠️ Exécutez la cellule dataset ci-dessous avant de commencer !

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# DATASET FIL ROUGE — 30 développeurs
# ============================================================
# Colonnes : experience, nb_langages, niveau_etudes,
#            taille_entreprise, remote, salaire
noms_colonnes = ["experience", "nb_langages", "niveau_etudes",
                 "taille_entreprise", "remote", "salaire"]

data = np.array([
    [ 0, 2, 3,  150,  80, 28.0],  # 0  junior
    [ 1, 1, 2,   50, 100, 26.5],  # 1  autodidacte
    [ 1, 3, 4,  800,  40, 35.0],  # 2  sortie ecole
    [ 2, 2, 3,  200,  60, 32.0],  # 3
    [ 2, 4, 4, 3000,  20, 38.0],  # 4
    [ 0, 1, 1,   30,  50, 25.0],  # 5  debutant
    [ 3, 3, 3,  100,  80, 34.5],  # 6
    [ 1, 5, 4,   15, 100, 42.0],  # 7  junior polyglotte
    [ 4, 3, 3,  500,  60, 38.5],  # 8
    [ 5, 4, 4, 1200,  40, 44.0],  # 9
    [ 5, 3, 3,  300,  80, 41.0],  # 10
    [ 6, 5, 4, 2000,  30, 48.0],  # 11
    [ 6, 4, 3,  150,  90, 43.5],  # 12
    [ 7, 5, 4,  800,  50, 50.0],  # 13
    [ 7, 3, 2,   80,  70, 39.0],  # 14 exp mais Bac+2
    [ 4, 6, 5,  400, 100, 47.0],  # 15
    [ 8, 4, 4, 1500,  40, 51.0],  # 16
    [ 5, 2, 3, 4000,  10, 40.0],  # 17
    [ 9, 5, 4,  600,  60, 52.0],  # 18
    [10, 6, 4, 2500,  30, 55.0],  # 19
    [10, 4, 3,  200,  80, 48.5],  # 20
    [11, 5, 5, 1000,  50, 58.0],  # 21
    [12, 7, 4, 3500,  20, 60.0],  # 22
    [ 9, 3, 3,   60,  90, 42.0],  # 23 senior sous-paye
    [13, 6, 4,  800,  70, 62.0],  # 24
    [11, 4, 4, 5000,  10, 54.0],  # 25
    [15, 8, 4, 1200,  50, 65.0],  # 26
    [17, 6, 5, 2000,  40, 68.0],  # 27
    [20, 7, 4,  500,  60, 72.0],  # 28
    [18, 5, 3,  100,  80, 58.0],  # 29
])

experience = data[:, 0]
nb_langages = data[:, 1]
salaire = data[:, 5]
salaire_eleve = (salaire > 45).astype(int)
n = len(data)

print(f"Dataset charge : {n} developpeurs, {data.shape[1]} colonnes")
print(f"Classe 0 (<=45k) : {np.sum(salaire_eleve==0)}, Classe 1 (>45k) : {np.sum(salaire_eleve==1)}")

# %% [markdown]
# ---
# ## Exercice 1 — Descente de gradient 1D ⭐⭐
# > $J(w) = (w-3)^2$, $J'(w) = 2(w-3)$, $w_0 = 0$, $\alpha = 0.1$

# %%
def J(w): return (w - 3) ** 2
def dJ(w): return 2 * (w - 3)

w = ______       # À COMPLÉTER : point de départ
alpha = ______   # À COMPLÉTER : taux d'apprentissage
n_iter = 20

for i in range(n_iter):
    grad = ______          # À COMPLÉTER : calculer la dérivée
    w = w - ______ * ______  # À COMPLÉTER : mise à jour
    if i < 5 or i == n_iter-1:
        print(f"Iter {i+1:2d} : w = {w:.4f}, J = {J(w):.4f}")

print(f"\nRésultat : w = {w:.4f} (optimal : 3.0)")

# %% [markdown]
# ---
# ## Exercice 2 — Visualiser la convergence ⭐⭐

# %%
def J(w): return (w - 3) ** 2
def dJ(w): return 2 * (w - 3)

w = -2.0; alpha = 0.15; n_iter = 25
hist_w = [w]; hist_J = [J(w)]

for i in range(n_iter):
    w = w - alpha * dJ(w)
    hist_w.append(w)
    hist_J.append(______)  # À COMPLÉTER : J(w)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))
w_range = np.linspace(-3, 8, 200)
ax1.plot(w_range, J(w_range), 'b-', lw=2)
ax1.plot(hist_w, hist_J, 'ro-', markersize=5, label='Itérations')
ax1.set_xlabel('w'); ax1.set_ylabel('J(w)'); ax1.legend(); ax1.grid(True, alpha=0.3)

ax2.plot(range(len(hist_J)), hist_J, 'g-o', markersize=4)
ax2.set_xlabel('Itération'); ax2.set_ylabel('J(w)'); ax2.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## Exercice 3 — Régression par gradient descent sur le dataset ⭐⭐

# %%
x = experience; y = salaire; n = len(y)

w1, w0 = 0.0, 0.0
alpha = ______    # À COMPLÉTER : essayer 0.001
n_iter = 5000
hist_mse = []

for it in range(n_iter):
    y_pred = ______ * x + ______        # À COMPLÉTER : w1*x + w0
    errors = y - y_pred
    dw1 = ______ * np.sum(______)       # À COMPLÉTER : -2/n * sum(x * errors)
    dw0 = ______ * np.sum(______)       # À COMPLÉTER : -2/n * sum(errors)
    w1 = w1 - alpha * ______            # À COMPLÉTER
    w0 = w0 - alpha * ______            # À COMPLÉTER
    hist_mse.append(np.mean(errors ** 2))

print(f"Résultat : ŷ = {w1:.4f}x + {w0:.4f}")
print(f"MSE = {hist_mse[-1]:.2f}")

# %% [markdown]
# ---
# ## Exercice 4 — Comparer 4 taux d'apprentissage ⭐⭐⭐

# %%
# À ÉCRIRE ENTIÈREMENT
# Tester alpha = 0.001, 0.01, 0.1, 0.9 sur f(w) = (w-5)²
# Tracer les 4 courbes de convergence sur un même graphique

# %% [markdown]
# ---
# ## Exercice 5 — Gradient descent vs scikit-learn ⭐⭐⭐

# %%
# À ÉCRIRE ENTIÈREMENT
# 1. Implémenter GD (10000 itérations) sur experience → salaire
# 2. Utiliser sklearn LinearRegression
# 3. Afficher tableau comparatif (w1, w0, MSE)
# 4. Tracer les deux droites superposées + courbe de convergence
# Indice : from sklearn.linear_model import LinearRegression
