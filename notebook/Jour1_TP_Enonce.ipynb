# %% [markdown]
# # Mathématiques appliquées à l'Intelligence Artificielle
# ## 📝 Jour 1 : Données et représentation mathématique
# ## TP Énoncé
#
# 2e année Bachelor Informatique
#
# ---
#
# > © 2025 Mohamed EL AFRIT
# > Ce contenu est distribué sous licence [Creative Commons BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr)
# > [www.mohamedelafrit.com](https://www.mohamedelafrit.com)

# %% [markdown]
# ## 🎯 Consignes
#
# - Complétez les cellules marquées `# À COMPLÉTER`
# - Exécutez chaque cellule dans l'ordre (Shift + Entrée)
# - Les exercices suivent la progression du cours
#
# > ⚠️ **N'oubliez pas** d'exécuter la cellule du dataset ci-dessous avant tout !

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# DATASET FIL ROUGE — 30 développeurs
# ============================================================
# Colonnes : experience, nb_langages, niveau_etudes,
#            taille_entreprise, remote, salaire
noms_colonnes = ["experience", "nb_langages", "niveau_etudes",
                 "taille_entreprise", "remote", "salaire"]

data = np.array([
    [ 0, 2, 3,  150,  80, 28.0],  # 0  junior
    [ 1, 1, 2,   50, 100, 26.5],  # 1  autodidacte
    [ 1, 3, 4,  800,  40, 35.0],  # 2  sortie ecole
    [ 2, 2, 3,  200,  60, 32.0],  # 3
    [ 2, 4, 4, 3000,  20, 38.0],  # 4
    [ 0, 1, 1,   30,  50, 25.0],  # 5  debutant
    [ 3, 3, 3,  100,  80, 34.5],  # 6
    [ 1, 5, 4,   15, 100, 42.0],  # 7  junior polyglotte
    [ 4, 3, 3,  500,  60, 38.5],  # 8
    [ 5, 4, 4, 1200,  40, 44.0],  # 9
    [ 5, 3, 3,  300,  80, 41.0],  # 10
    [ 6, 5, 4, 2000,  30, 48.0],  # 11
    [ 6, 4, 3,  150,  90, 43.5],  # 12
    [ 7, 5, 4,  800,  50, 50.0],  # 13
    [ 7, 3, 2,   80,  70, 39.0],  # 14 exp mais Bac+2
    [ 4, 6, 5,  400, 100, 47.0],  # 15
    [ 8, 4, 4, 1500,  40, 51.0],  # 16
    [ 5, 2, 3, 4000,  10, 40.0],  # 17
    [ 9, 5, 4,  600,  60, 52.0],  # 18
    [10, 6, 4, 2500,  30, 55.0],  # 19
    [10, 4, 3,  200,  80, 48.5],  # 20
    [11, 5, 5, 1000,  50, 58.0],  # 21
    [12, 7, 4, 3500,  20, 60.0],  # 22
    [ 9, 3, 3,   60,  90, 42.0],  # 23 senior sous-paye
    [13, 6, 4,  800,  70, 62.0],  # 24
    [11, 4, 4, 5000,  10, 54.0],  # 25
    [15, 8, 4, 1200,  50, 65.0],  # 26
    [17, 6, 5, 2000,  40, 68.0],  # 27
    [20, 7, 4,  500,  60, 72.0],  # 28
    [18, 5, 3,  100,  80, 58.0],  # 29
])

experience = data[:, 0]
nb_langages = data[:, 1]
salaire = data[:, 5]
salaire_eleve = (salaire > 45).astype(int)
n = len(data)

print(f"Dataset charge : {n} developpeurs, {data.shape[1]} colonnes")
print(f"Classe 0 (<=45k) : {np.sum(salaire_eleve==0)}, Classe 1 (>45k) : {np.sum(salaire_eleve==1)}")
# Out:
# Dataset charge : 30 developpeurs, 6 colonnes
# Classe 0 (<=45k) : 15, Classe 1 (>45k) : 15

# %% [markdown]
# ---
# ## Exercice 8 — Créer et manipuler des vecteurs NumPy ⭐⭐
#
# > **Rappel** : Un vecteur $\mathbf{x} \in \mathbb{R}^p$ se crée avec `np.array([...])`.
# > Le développeur #3 a : experience=2, nb_langages=2, niveau_etudes=3, taille_entreprise=200, remote=60.

# %%
# 1. Créer le vecteur du développeur #3 du dataset
x3 = np.array([______])  # À COMPLÉTER : 5 features

# 2. Afficher la dimension
print(f"Dimension de x3 : {______}")  # À COMPLÉTER : utiliser len() ou .shape[0]

# 3. Accéder à la 3e composante (niveau d'études)
niveau = ______  # À COMPLÉTER : x3[?]
print(f"Niveau d'études : {niveau}")

# 4. Calculer la norme du vecteur
# Rappel : ||x|| = sqrt(x1² + x2² + ... + xp²)
norme = np.sqrt(np.______(x3 ** 2))  # À COMPLÉTER : quelle fonction numpy ?
print(f"Norme de x3 : {norme:.2f}")

# 5. Créer le vecteur du développeur #5 (experience=0, langages=1, etudes=1, taille=30, remote=50)
x5 = np.array([______])  # À COMPLÉTER

# 6. Produit scalaire de x3 et x5
ps = ______  # À COMPLÉTER : utiliser l'opérateur @
print(f"Produit scalaire x3 · x5 = {ps}")

# 7. Distance entre les deux développeurs
distance = np.sqrt(np.sum((______ - ______) ** 2))  # À COMPLÉTER
print(f"Distance : {distance:.2f}")

# %% [markdown]
# ---
# ## Exercice 9 — Construire la matrice du dataset ⭐⭐
#
# > **Rappel** : La matrice $\mathbf{X} \in \mathbb{R}^{n \times p}$ contient une ligne par observation.
# > Slicing NumPy : `X[ligne, colonne]`, `X[:, 0]` = toute la colonne 0.

# %%
# Construire une mini-matrice avec 5 développeurs (#0 à #4)
X_mini = np.array([
    [0, 2, 3, 150, 80],    # dev #0
    [______],               # À COMPLÉTER : dev #1 (1,1,2,50,100)
    [______],               # À COMPLÉTER : dev #2 (1,3,4,800,40)
    [______],               # À COMPLÉTER : dev #3 (2,2,3,200,60)
    [______],               # À COMPLÉTER : dev #4 (2,4,4,3000,20)
])

print(f"Shape de X_mini : {X_mini.shape}")

# Extraire la colonne expérience
experience_mini = X_mini[:, ______]  # À COMPLÉTER : quel indice ?
print(f"Expériences : {experience_mini}")

# Extraire le dev #4 (ligne complète)
dev4 = X_mini[______, :]  # À COMPLÉTER : quel indice ?
print(f"Dev #4 : {dev4}")

# Multiplier la matrice par un vecteur de poids
w = np.array([2.0, 1.5, 3.0, 0.001, -0.1])
y_pred = ______ @ ______ + 20  # À COMPLÉTER : X_mini @ w + biais
print(f"Prédictions : {y_pred}")

# %% [markdown]
# ---
# ## Exercice 10 — Régression linéaire from scratch ⭐⭐
#
# > **Rappel** : Droite de régression $\hat{y} = w_1 x + w_0$ avec :
# > $$w_0 = \bar{y} - w_1 \bar{x}$$
# >
# > $$w_1 = \frac{\sum(x_i - \bar{x})(y_i - \bar{y})}{\sum(x_i - \bar{x})^2} \qquad $$
# >
# > $$\text{MSE} = \frac{1}{n}\sum(y_i - \hat{y}_i)^2$$

# %%
x = experience  # feature : années d'expérience
y = salaire     # cible : salaire en k€

# 1. Calculer les moyennes
x_mean = ______  # À COMPLÉTER
y_mean = ______  # À COMPLÉTER

# 2. Calculer w1 (pente) par la formule des moindres carrés
numerateur = np.sum((x - x_mean) * (______ - ______))  # À COMPLÉTER
denominateur = np.sum((x - ______) ** 2)                # À COMPLÉTER
w1 = numerateur / denominateur
print(f"w1 (pente) = {w1:.4f}")

# 3. Calculer w0 (ordonnée à l'origine)
w0 = ______ - ______ * ______  # À COMPLÉTER : y_mean - w1 * x_mean
print(f"w0 (biais) = {w0:.4f}")

# 4. Calculer les prédictions
y_pred = ______ * x + ______  # À COMPLÉTER
print(f"Premières prédictions : {y_pred[:5].round(1)}")

# 5. Calculer le MSE
mse = np.mean((______ - ______) ** 2)  # À COMPLÉTER
print(f"MSE = {mse:.2f}")

# 6. Tracer le graphique
fig, ax = plt.subplots(figsize=(9, 5))
ax.scatter(x, y, c='blue', s=40, label='Données')
xl = np.linspace(0, 21, 100)
ax.plot(xl, w1*xl+w0, 'r-', lw=2, label=f'ŷ = {w1:.2f}x + {w0:.2f}')
ax.set_xlabel("Expérience"); ax.set_ylabel("Salaire (k€)")
ax.set_title(f"Régression linéaire (MSE = {mse:.2f})")
ax.legend(); ax.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## Exercice 11 — Exploration complète du dataset ⭐⭐⭐
#
# Écrire un programme **complet** (sans squelette) qui :
#
# 1. Calcule les **statistiques descriptives** (moyenne, écart-type, min, max) de chaque colonne
# 2. Calcule la **corrélation** de chaque feature avec le salaire : `np.corrcoef(feature, salaire)[0,1]`
# 3. Trace **5 scatter plots** (un par feature vs salaire) dans une figure `plt.subplots(1, 5)`
# 4. Identifie la feature la plus corrélée et la moins corrélée au salaire

# %%
# Exercice 4 — À ÉCRIRE ENTIÈREMENT
# Votre code ici...

# %% [markdown]
# ---
# ## Exercice 12 — Comparer 3 modèles de régression ⭐⭐⭐
#
# Écrire un programme qui :
#
# 1. Entraîne 3 modèles de régression sur le dataset :
#    - **Modèle A** : `ŷ = w₁ × experience + w₀`  (1 feature)
#    - **Modèle B** : `ŷ = w₁ × experience + w₂ × nb_langages + w₀`  (2 features, poids manuels)
#    - **Modèle C** : `ŷ = w₁ × experience + w₂ × nb_langages + w₀`  (2 features, moindres carrés via `np.linalg.lstsq`)
# 2. Calcule le MSE de chaque modèle
# 3. Trace les 3 droites superposées sur un même graphique
# 4. Affiche un tableau comparatif

# %%
# Exercice 5 — À ÉCRIRE ENTIÈREMENT
# Indice : np.linalg.lstsq(X_aug, y, rcond=None)[0] donne les poids optimaux
# X_aug = np.column_stack([X_2features, np.ones(n)])  # ajouter colonne de 1 pour le biais
