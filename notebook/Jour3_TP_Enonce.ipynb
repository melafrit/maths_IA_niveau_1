# %% [markdown]
# # Mathématiques appliquées à l'Intelligence Artificielle
# ## 📝 Jour 3 : Probabilités et classification
# ## TP Énoncé
#
# 2e année Bachelor Informatique
#
# ---
#
# > © 2025 Mohamed EL AFRIT
# > Ce contenu est distribué sous licence [Creative Commons BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr)
# > [www.mohamedelafrit.com](https://www.mohamedelafrit.com)

# %% [markdown]
# ## ⚠️ Exécutez la cellule dataset ci-dessous avant de commencer !

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# DATASET FIL ROUGE — 30 développeurs
# ============================================================
# Colonnes : experience, nb_langages, niveau_etudes,
#            taille_entreprise, remote, salaire
noms_colonnes = ["experience", "nb_langages", "niveau_etudes",
                 "taille_entreprise", "remote", "salaire"]

data = np.array([
    [ 0, 2, 3,  150,  80, 28.0],  # 0  junior
    [ 1, 1, 2,   50, 100, 26.5],  # 1  autodidacte
    [ 1, 3, 4,  800,  40, 35.0],  # 2  sortie ecole
    [ 2, 2, 3,  200,  60, 32.0],  # 3
    [ 2, 4, 4, 3000,  20, 38.0],  # 4
    [ 0, 1, 1,   30,  50, 25.0],  # 5  debutant
    [ 3, 3, 3,  100,  80, 34.5],  # 6
    [ 1, 5, 4,   15, 100, 42.0],  # 7  junior polyglotte
    [ 4, 3, 3,  500,  60, 38.5],  # 8
    [ 5, 4, 4, 1200,  40, 44.0],  # 9
    [ 5, 3, 3,  300,  80, 41.0],  # 10
    [ 6, 5, 4, 2000,  30, 48.0],  # 11
    [ 6, 4, 3,  150,  90, 43.5],  # 12
    [ 7, 5, 4,  800,  50, 50.0],  # 13
    [ 7, 3, 2,   80,  70, 39.0],  # 14 exp mais Bac+2
    [ 4, 6, 5,  400, 100, 47.0],  # 15
    [ 8, 4, 4, 1500,  40, 51.0],  # 16
    [ 5, 2, 3, 4000,  10, 40.0],  # 17
    [ 9, 5, 4,  600,  60, 52.0],  # 18
    [10, 6, 4, 2500,  30, 55.0],  # 19
    [10, 4, 3,  200,  80, 48.5],  # 20
    [11, 5, 5, 1000,  50, 58.0],  # 21
    [12, 7, 4, 3500,  20, 60.0],  # 22
    [ 9, 3, 3,   60,  90, 42.0],  # 23 senior sous-paye
    [13, 6, 4,  800,  70, 62.0],  # 24
    [11, 4, 4, 5000,  10, 54.0],  # 25
    [15, 8, 4, 1200,  50, 65.0],  # 26
    [17, 6, 5, 2000,  40, 68.0],  # 27
    [20, 7, 4,  500,  60, 72.0],  # 28
    [18, 5, 3,  100,  80, 58.0],  # 29
])

experience = data[:, 0]
nb_langages = data[:, 1]
salaire = data[:, 5]
salaire_eleve = (salaire > 45).astype(int)
n = len(data)

print(f"Dataset charge : {n} developpeurs, {data.shape[1]} colonnes")
print(f"Classe 0 (<=45k) : {np.sum(salaire_eleve==0)}, Classe 1 (>45k) : {np.sum(salaire_eleve==1)}")

# %% [markdown]
# ---
# ## Exercice 1 — Probabilités empiriques ⭐⭐
# > $P(A) = \frac{\text{cas favorables}}{\text{total}}$, $P(A|B) = \frac{P(A \cap B)}{P(B)}$

# %%
# 1. P(salaire_eleve = 1)
p1 = ______  # À COMPLÉTER : np.mean(salaire_eleve)
print(f"P(sal>45k) = {p1:.2f}")

# 2. P(sal>45k | experience > 10)
mask_exp10 = ______  # À COMPLÉTER : experience > 10
p_cond = np.mean(______)  # À COMPLÉTER : salaire_eleve filtré
print(f"P(sal>45k | exp>10) = {p_cond:.2f}")

# 3. P(sal>45k | nb_langages >= 5)
mask_lang = ______  # À COMPLÉTER
p_lang = np.mean(______)  # À COMPLÉTER
print(f"P(sal>45k | lang≥5) = {p_lang:.2f}")

# %% [markdown]
# ---
# ## Exercice 2 — Règle de décision et frontière ⭐⭐
# > $g(\mathbf{x}) = \mathbf{w}^T\mathbf{x} + b$, frontière : $g(\mathbf{x}) = 0$

# %%
X = data[:, :2]; y = salaire_eleve
w = np.array([______, ______])  # À COMPLÉTER : essayer 0.5, 0.8
b = ______  # À COMPLÉTER : essayer -4

scores = ______  # À COMPLÉTER : X @ w + b
y_pred = (scores > 0).astype(int)
acc = np.mean(______)  # À COMPLÉTER : y_pred == y
print(f"Accuracy = {acc:.0%}")

# Graphique
fig, ax = plt.subplots(figsize=(8, 6))
for c, color, label in [(0,'#e74c3c','≤ 45k'),(1,'#2ecc71','> 45k')]:
    mask = y == c
    ax.scatter(X[mask,0], X[mask,1], c=color, s=70, label=label, edgecolors='white')
x1_line = np.linspace(-1, 21, 100)
x2_line = ______  # À COMPLÉTER : -(w[0]/w[1]) * x1_line - b/w[1]
ax.plot(x1_line, x2_line, 'k--', lw=2, label='Frontière')
ax.set_xlim(-1,21); ax.set_ylim(0,9); ax.legend(); ax.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## Exercice 3 — Perceptron from scratch ⭐⭐

# %%
X = data[:, :2]; y = salaire_eleve
w = np.zeros(2); b = 0.0; alpha = ______  # À COMPLÉTER

for epoch in range(100):
    n_errors = 0
    for i in range(n):
        z = ______  # À COMPLÉTER : w @ X[i] + b
        y_pred = ______  # À COMPLÉTER : 1 if z > 0 else 0
        if y_pred != y[i]:
            error = ______  # À COMPLÉTER : y[i] - y_pred
            w = w + ______  # À COMPLÉTER : alpha * error * X[i]
            b = b + ______  # À COMPLÉTER : alpha * error
            n_errors += 1
    if epoch < 5 or epoch % 20 == 19:
        acc = np.mean([(1 if (w@X[j]+b)>0 else 0)==y[j] for j in range(n)])
        print(f"Epoch {epoch+1:3d} : erreurs={n_errors}, acc={acc:.0%}")

# %% [markdown]
# ---
# ## Exercice 4 — Perceptron vs sklearn ⭐⭐⭐

# %%
# À ÉCRIRE ENTIÈREMENT
# 1. Perceptron from scratch (100 époques)
# 2. sklearn : from sklearn.linear_model import Perceptron
# 3. Tableau comparatif (w1, w2, b, accuracy)
# 4. Tracer les 2 frontières sur le même graphique

# %% [markdown]
# ---
# ## Exercice 5 — Perceptron sur XOR ⭐⭐⭐

# %%
# À ÉCRIRE ENTIÈREMENT
# 1. Entraîner un perceptron sur XOR (200 époques)
# 2. Montrer qu'il ne converge pas
# 3. Bonus : ajouter x3 = x1*x2 et réessayer
