# %% [markdown]
# # Mathématiques appliquées à l'Intelligence Artificielle
# ## 📝 Jour 4 : Réseaux de neurones
# ## TP Énoncé
#
# 2e année Bachelor Informatique
#
# ---
#
# > © 2025 Mohamed EL AFRIT
# > Ce contenu est distribué sous licence [Creative Commons BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr)
# > [www.mohamedelafrit.com](https://www.mohamedelafrit.com)

# %% [markdown]
# ## ⚠️ Exécutez la cellule dataset ci-dessous avant de commencer !

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# DATASET FIL ROUGE — 30 développeurs
# ============================================================
# Colonnes : experience, nb_langages, niveau_etudes,
#            taille_entreprise, remote, salaire
noms_colonnes = ["experience", "nb_langages", "niveau_etudes",
                 "taille_entreprise", "remote", "salaire"]

data = np.array([
    [ 0, 2, 3,  150,  80, 28.0],  # 0  junior
    [ 1, 1, 2,   50, 100, 26.5],  # 1  autodidacte
    [ 1, 3, 4,  800,  40, 35.0],  # 2  sortie ecole
    [ 2, 2, 3,  200,  60, 32.0],  # 3
    [ 2, 4, 4, 3000,  20, 38.0],  # 4
    [ 0, 1, 1,   30,  50, 25.0],  # 5  debutant
    [ 3, 3, 3,  100,  80, 34.5],  # 6
    [ 1, 5, 4,   15, 100, 42.0],  # 7  junior polyglotte
    [ 4, 3, 3,  500,  60, 38.5],  # 8
    [ 5, 4, 4, 1200,  40, 44.0],  # 9
    [ 5, 3, 3,  300,  80, 41.0],  # 10
    [ 6, 5, 4, 2000,  30, 48.0],  # 11
    [ 6, 4, 3,  150,  90, 43.5],  # 12
    [ 7, 5, 4,  800,  50, 50.0],  # 13
    [ 7, 3, 2,   80,  70, 39.0],  # 14 exp mais Bac+2
    [ 4, 6, 5,  400, 100, 47.0],  # 15
    [ 8, 4, 4, 1500,  40, 51.0],  # 16
    [ 5, 2, 3, 4000,  10, 40.0],  # 17
    [ 9, 5, 4,  600,  60, 52.0],  # 18
    [10, 6, 4, 2500,  30, 55.0],  # 19
    [10, 4, 3,  200,  80, 48.5],  # 20
    [11, 5, 5, 1000,  50, 58.0],  # 21
    [12, 7, 4, 3500,  20, 60.0],  # 22
    [ 9, 3, 3,   60,  90, 42.0],  # 23 senior sous-paye
    [13, 6, 4,  800,  70, 62.0],  # 24
    [11, 4, 4, 5000,  10, 54.0],  # 25
    [15, 8, 4, 1200,  50, 65.0],  # 26
    [17, 6, 5, 2000,  40, 68.0],  # 27
    [20, 7, 4,  500,  60, 72.0],  # 28
    [18, 5, 3,  100,  80, 58.0],  # 29
])

experience = data[:, 0]
nb_langages = data[:, 1]
salaire = data[:, 5]
salaire_eleve = (salaire > 45).astype(int)
n = len(data)

print(f"Dataset charge : {n} developpeurs, {data.shape[1]} colonnes")
print(f"Classe 0 (<=45k) : {np.sum(salaire_eleve==0)}, Classe 1 (>45k) : {np.sum(salaire_eleve==1)}")

# %% [markdown]
# ---
# ## Exercice 1 — Sigmoïde et ReLU ⭐⭐
# > $\sigma(z) = \frac{1}{1+e^{-z}}$, $\text{ReLU}(z) = \max(0, z)$

# %%
def sigmoid(z):
    return ______  # À COMPLÉTER

def relu(z):
    return ______  # À COMPLÉTER

# Tester
valeurs = np.array([-3, -1, 0, 1, 2, 5])
print("sigmoid :", np.round(sigmoid(valeurs), 4))
print("relu    :", relu(valeurs))

# Tracer
z = np.linspace(-6, 6, 200)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(z, ______, 'b-', lw=2)  # À COMPLÉTER
ax1.set_title("Sigmoïde"); ax1.grid(True, alpha=0.3)
ax2.plot(z, ______, 'r-', lw=2)  # À COMPLÉTER
ax2.set_title("ReLU"); ax2.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## Exercice 2 — Forward pass 2-2-1 ⭐⭐
# > $\mathbf{h} = \sigma(\mathbf{W}^{(1)}\mathbf{x} + \mathbf{b}^{(1)})$, $\hat{y} = \sigma(\mathbf{w}^{(2)T}\mathbf{h} + b^{(2)})$

# %%
def sigmoid(z): return 1/(1+np.exp(-z))
x = np.array([5.0, 4.0])
W1 = np.array([[0.3, 0.5], [-0.2, 0.4]]); b1 = np.array([-2.0, 0.5])
w2 = np.array([0.8, 0.6]); b2 = -0.5

z1 = ______  # À COMPLÉTER : W1 @ x + b1
h  = ______  # À COMPLÉTER : sigmoid(z1)
z2 = ______  # À COMPLÉTER : w2 @ h + b2
y_pred = ______  # À COMPLÉTER : sigmoid(z2)

print(f"h = {np.round(h, 4)}, ŷ = {y_pred:.4f}")
print(f"Classe : {1 if y_pred > 0.5 else 0}")

# %% [markdown]
# ---
# ## Exercice 3 — Réseau XOR avec backpropagation ⭐⭐

# %%
def sigmoid(z): return 1/(1+np.exp(-z))
def sigmoid_d(a): return a*(1-a)

X = np.array([[0,0],[0,1],[1,0],[1,1]], dtype=float)
y = np.array([[0],[1],[1],[0]], dtype=float)

np.random.seed(42)
W1 = np.random.randn(2,4)*0.5; b1 = np.zeros((1,4))
W2 = np.random.randn(4,1)*0.5; b2 = np.zeros((1,1))

for epoch in range(5000):
    z1 = ______  # À COMPLÉTER : X @ W1 + b1
    h  = ______  # À COMPLÉTER : sigmoid(z1)
    z2 = ______  # À COMPLÉTER : h @ W2 + b2
    out = ______  # À COMPLÉTER : sigmoid(z2)
    loss = np.mean((y - out)**2)

    d_out = (out - y) * sigmoid_d(out)
    dW2 = ______  # À COMPLÉTER : h.T @ d_out / 4
    db2 = np.mean(d_out, axis=0, keepdims=True)
    d_h = d_out @ W2.T * sigmoid_d(h)
    dW1 = ______  # À COMPLÉTER : X.T @ d_h / 4
    db1 = np.mean(d_h, axis=0, keepdims=True)

    W2 -= 1.0*dW2; b2 -= 1.0*db2; W1 -= 1.0*dW1; b1 -= 1.0*db1
    if epoch%1000==999: print(f"Epoch {epoch+1} : loss={loss:.4f}")

print(f"\nPrédictions : {out.flatten().round(3)}")

# %% [markdown]
# ---
# ## Exercice 4 — Réseau from scratch sur salaire_eleve ⭐⭐⭐

# %%
# À ÉCRIRE ENTIÈREMENT
# 1. Normaliser X (experience, nb_langages)
# 2. Réseau 2-4-1, sigmoïde, alpha=0.5, 2000 époques
# 3. Afficher loss + accuracy toutes les 500 époques
# 4. Tracer : courbe de convergence + surface de décision (contourf)
# 5. Comparer avec le perceptron du Jour 3

# %% [markdown]
# ---
# ## Exercice 5 — NumPy vs sklearn MLPClassifier ⭐⭐⭐

# %%
# À ÉCRIRE ENTIÈREMENT
# from sklearn.neural_network import MLPClassifier
# from sklearn.preprocessing import StandardScaler
# 1. From scratch (exercice 4)
# 2. MLPClassifier(hidden_layer_sizes=(4,), max_iter=2000, activation='logistic')
# 3. Tableau comparatif : accuracy + nb paramètres
# 4. 3 surfaces de décision côte à côte (from scratch / sklearn / perceptron)
